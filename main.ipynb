# %% [markdown]
# # Data Structures & Algorithms
#
# todo
#
# ## Introduction
#
# todo
#
# ## Methodology
#
# ## Index
#
# ## Big-0 Notiona
#
# ### Time Complexity
#
# ### Space Complexity
#
# ### Tree
# - `Node` class
# - `make_perfect_tree`, `print_tree`
# - `serialize`, `deserialize`
# - `bfs_level_order`, `dfs_preorder`, `dfs_inorder`, `dfs_postorder`
# - `right_view`, `left_view`, `top_view`, `bottom_view`
# - `height`, `is_same_tree`, `is_symmetrical`, `is_valid_bst`, `is_subtree`
# - `invert_tree`, `lowest_common_ancestor`, `diameter_of_binary_tree`, `has_path_sum`
#
# ### BST
# - `TreeNode` class
# - `insert`, `search`, `delete`
# - `inorder_traversal`, `max_bst`
# - `floor`, `ceil`, `inorder_successor`
# - `is_valid_bst`, `kth_smallest_element`
#
# ### Linked List
# - `ListNode`, `DoublyListNode` classes
# - `make_singly_linked_list`, `print_linked_list`
# - `get_length`, `search_list`, `delete_node_by_key`
# - `has_cycle`, `reverse_list`, `find_middle_node`
# - `merge_two_sorted_lists`, `remove_nth_from_end`
# - `reorder_list`, `RandomListNode`, `copy_random_list`
#
# ### Stack
# - `Stack` class
# - `is_valid_parentheses`, `daily_temperatures`
# - `evaluate_reverse_polish_notation`, `generate_parentheses`
# - `MinStack` class
#
# ### Queue
# - `QueueWithList`, `Queue`, `MovingAverage`, `MyCircularQueue` classes
# - `number_of_islands`
#
# ### Hashmap
# - `HashTable` class
# - `two_sum`, `is_valid_anagram`, `group_anagrams`, `first_unique_char`
# - `LoggerRateLimiter` class
# - `LRUCache` class
#
# ### Heap
# - `MinHeap` class
# - `KthLargest` class
# - `MedianFinder` class
# - `merge_k_sorted_lists`
# - `top_k_frequent_elements`
# - `task_scheduler`
# - `k_smallest_pairs`
#
# ### Matrix
# - `dfs_traversal`, `bfs_traversal`, `spiral_traversal`
# - `rotate_90_degrees_clockwise`, `set_matrix_zeroes`
# - `search_in_2d_matrix`
#
# ### Adjacency Matrix
# - `Graph` class
# - `add_edge`, `remove_edge`, `get_neighbors`
# - `bfs`, `dfs`
# - `shortest_path_unweighted`
#
# ### Graph
# - `GraphNode` class
# - `Graph` class
# - `bfs`, `dfs`
# - `is_cycle_undirected`, `is_cycle_directed`
# - `dijkstra_shortest_path`, `shortest_path_unweighted`
# - `prim_mst`, `topological_sort`
# - `UnionFind` class
# - `number_of_islands`, `rotten_tomatoes`, `flood_fill`
# - `visualize_graph_turtle`
#
# ### Graph Adj
# - `Graph` class
# - `bfs`, `dfs`
# - `is_cycle_undirected`, `is_cycle_directed`
# - `dijkstra_shortest_path`, `shortest_path_unweighted`
# - `prim_mst`, `topological_sort`
# - `UnionFind` class
# - `number_of_islands`, `rotten_tomatoes`, `flood_fill`
# - `visualize_graph_turtle`
#
# ### Sorting
# - `bubble_sort`, `selection_sort`, `insertion_sort`
# - `merge_sort`, `quick_sort`, `heap_sort`, `counting_sort`
#
# ### Bitmask
# - `get_bit`, `set_bit`, `clear_bit`
# - `generate_all_subsets`
# - `count_set_bits`
# - `single_number`
# - `is_power_of_two`
#
# ### Ordered Set
# - `simulate_ordered_set_with_bisect`
# - `FenwickTree` class
# - `count_smaller_numbers_after_self`
# - `contains_nearby_almost_duplicate`
#
# ### Prefix Sum
# - `prefix_sum_template`
# - `subarray_sum_equals_k`
# - `NumArray` class
# - `find_pivot_index`
#
# ### Monotonic Stack
# - `monotonic_stack_template`
# - `next_greater_element_i`
# - `daily_temperatures`
# - `remove_k_digits`
#
# ### Sliding Window
# - `sliding_window_template`
# - `max_subarr_of_size_k`
# - `smallest_subarray_with_given_sum`
# - `find_string_anagrams`
#
# ### Binary Search
# - `binary_search_exact`
# - `find_first_occurrence`, `find_last_occurrence`
# - `search_in_rotated_sorted_array`
# - `find_min_in_rotated_sorted_array`
# - `find_peak_element`
# - `search_a_2d_matrix_ii`
#
# ### Greedy
# - `greedy_algorithm_template`
# - `max_subarray`
# - `can_jump`
# - `merge_intervals`
# - `can_complete_circuit`
#
# ### Divide & Conquer
# - `merge_sort`, `_merge`
# - `quick_sort`
# - `binary_search`
# - `max_subarray_sum`, `_max_crossing_sum`
#
# ### Dynamic Programming
# - `fibonacci_memoization`, `fibonacci_tabulation`
# - `climbing_stairs`
# - `longest_common_subsequence`
# - `coin_change`
# - `knapsack_01`
#
# ### Blank
# - Placeholder for custom or new algorithms

# %%
# Out:
# hello world
